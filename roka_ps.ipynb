# %% [markdown]
# <a href="https://colab.research.google.com/github/wlgns222/roka-problem-solving/blob/main/roka_ps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Greedy

# %% [markdown]
# ## **1429번 뒤집기**
#
# **문제**
#
# 다솜이는 0과 1로만 이루어진 문자열 S를 가지고 있다. 다솜이는 이 문자열 S에 있는 모든 숫자를 전부 같게 만들려고 한다. 다솜이가 할 수 있는 행동은 S에서 연속된 하나 이상의 숫자를 잡고 모두 뒤집는 것이다. 뒤집는 것은 1을 0으로, 0을 1로 바꾸는 것을 의미한다.
#
# 문자열 S가 주어졌을 때, 다솜이가 해야하는 행동의 최소 횟수를 출력하시오.

# %%
import sys

s = sys.stdin.readline().strip()

n_length = len(s)

count = 0

for n in range(n_length - 1):
    if s[n] != s[n+1]:
        count += 1

print((count + 1) // 2)
# Out:
# 0
